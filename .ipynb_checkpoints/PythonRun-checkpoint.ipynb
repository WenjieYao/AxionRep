# %%
#%%writefile PIT.py
import math
import meep as mp
from meep import mpb
# !rm *.h5
num_bands = 1

k_points = [mp.Vector3(),
            mp.Vector3(0.0  ,0.5  ,0.5  ),
            mp.Vector3(0.0  ,0.625,0.375),       
            mp.Vector3(0.0  ,0.5  ,0.0  ),  
            mp.Vector3(0.0  ,0.0  ,0.0  ),
            mp.Vector3(0.0  ,0.5  ,0.5  ),
            mp.Vector3(0.25 ,0.75 ,0.5  ),
            mp.Vector3(0.375,0.75 ,0.375),
            mp.Vector3()]          

res0 = 8
n0 = 1.5
tol = 0.001
mesh_size = 3
L = math.sqrt(3)/4
n = math.sqrt(32)
r = 0.0725
m = mp.Medium(epsilon=n*n)

geometry = [mp.Cylinder(center=mp.Vector3(0,0,0),radius=r, material=m, height=L, axis=mp.Vector3(1,1,1)),
           mp.Cylinder(center=mp.Vector3(0.5,0,0),radius=r, material=m, height=L, axis=mp.Vector3(3,-1,-1)),
           mp.Cylinder(center=mp.Vector3(0,0.5,0),radius=r, material=m, height=L, axis=mp.Vector3(-1,3,-1)),
           mp.Cylinder(center=mp.Vector3(0,0,0.5),radius=r, material=m, height=L, axis=mp.Vector3(-1,-1,3))]

#a = math.sqrt(0.5)
#geometry_lattice = mp.Lattice(basis-size=mp.Vector3(a,a,a),
#                                 basis1=mp.Vector3(0,1,1),
#                                 basis2=mp.Vector3(1,0,1),
#                                 basis3=mp.Vector3(1,1,0))

sqrt_half = math.sqrt(0.5)
geometry_lattice = mp.Lattice(
    basis_size=mp.Vector3(sqrt_half, sqrt_half, sqrt_half),
    basis1=mp.Vector3(0, 1, 1),
    basis2=mp.Vector3(1, 0, 1),
    basis3=mp.Vector3(1, 1)
)
k_points = mp.interpolate(1, k_points)

ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=res0*n/n0,
                    mesh_size = mesh_size)
#mpb.ModeSolver.optimize_grid_size()
print("Square lattice of rods: TE bands")
ms.run()
ms.output_epsilon()
# Out:
# rm: *.h5: No such file or directory
# Square lattice of rods: TE bands
# Initializing eigensolver data
# Computing 1 bands with 1e-07 tolerance
#      cylinder, center = (0,0,0)
#           radius 0.0725, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.5,0,0)
#           radius 0.0725, height 0.433013, axis (1.73205, -0.57735, -0.57735)
#      cylinder, center = (0,0.5,0)
#           radius 0.0725, height 0.433013, axis (-0.57735, 1.73205, -0.57735)
#      cylinder, center = (0,0,0.5)
#           radius 0.0725, height 0.433013, axis (-0.57735, -0.57735, 1.73205)
# 17 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.25, 0.25>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.5625, 0.4375>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.5625, 0.1875>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.25, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.25, 0.25>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.125, 0.625, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.3125, 0.75, 0.4375>
#   Vector3<0.375, 0.75, 0.375>
#   Vector3<0.1875, 0.375, 0.1875>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 1.11634397507
# elapsed time for k point: 0.0993649959564
# elapsed time for k point: 21.1717450619
# elapsed time for k point: 49.7314748764
# elapsed time for k point: 69.4507930279
# elapsed time for k point: 56.9445500374
# elapsed time for k point: 56.7504320145
# elapsed time for k point: 29.6365599632
# elapsed time for k point: 20.6576879025
# elapsed time for k point: 0.0571570396423
# elapsed time for k point: 20.6145720482
# elapsed time for k point: 49.1990280151
# elapsed time for k point: 17.5815179348
# elapsed time for k point: 100.31368494
# elapsed time for k point: 65.7464010715
# elapsed time for k point: 29.6289980412
# elapsed time for k point: 20.6867508888
# elapsed time for k point: 0.0614669322968
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.274313422394 at Vector3<0.25, 0.75, 0.5>
# total elapsed time for run: 609.453001976
# done
# Outputting epsilon.h5...

# %%
# !rm PI.dat
# !python PIT.py >& PI.out
# !grep freqs PI.out >> PI.dat

# %%
# !rm *.h5
# !rm *.vtk
# !python PIT.py 
# !h5tovtk PIT-epsilon.h5
# Out:
# rm: *.h5: No such file or directory
# rm: *.vtk: No such file or directory
# Square lattice of rods: TE bands
# Initializing eigensolver data
# Computing 3 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 63 x 63 x 63.
# Solving for 3 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.0725, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.5,0,0)
#           radius 0.0725, height 0.433013, axis (1.73205, -0.57735, -0.57735)
#      cylinder, center = (0,0.5,0)
#           radius 0.0725, height 0.433013, axis (-0.57735, 1.73205, -0.57735)
#      cylinder, center = (0,0,0.5)
#           radius 0.0725, height 0.433013, axis (-0.57735, -0.57735, 1.73205)
# Geometric object tree has depth 1 and 7 object nodes (vs. 4 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 41 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.1>
#   Vector3<0.0, 0.2, 0.2>
#   Vector3<0.0, 0.3, 0.3>
#   Vector3<0.0, 0.4, 0.4>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.525, 0.475>
#   Vector3<0.0, 0.55, 0.45>
#   Vector3<0.0, 0.575, 0.425>
#   Vector3<0.0, 0.6, 0.4>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.6, 0.3>
#   Vector3<0.0, 0.575, 0.225>
#   Vector3<0.0, 0.55, 0.15>
#   Vector3<0.0, 0.525, 0.075>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.3, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.1>
#   Vector3<0.0, 0.2, 0.2>
#   Vector3<0.0, 0.3, 0.3>
#   Vector3<0.0, 0.4, 0.4>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.05, 0.55, 0.5>
#   Vector3<0.1, 0.6, 0.5>
#   Vector3<0.15, 0.65, 0.5>
#   Vector3<0.2, 0.7, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.275, 0.75, 0.475>
#   Vector3<0.3, 0.75, 0.45>
#   Vector3<0.325, 0.75, 0.425>
#   Vector3<0.35, 0.75, 0.4>
#   Vector3<0.375, 0.75, 0.375>
#   Vector3<0.3, 0.6, 0.3>
#   Vector3<0.225, 0.45, 0.225>
#   Vector3<0.15, 0.3, 0.15>
#   Vector3<0.075, 0.15, 0.075>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.519435882568
# solve_kpoint (0,0,0):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3
# Solving for bands 3 to 3...
#     iteration   23: trace = 0.5369284088721843 (0.000390012% change)
# Finished solving for bands 3 to 3 after 30 iterations.
# freqs:, 1, 0, 0, 0, 0, 0, 0, 0.732752
# elapsed time for k point: 5.290361166
# solve_kpoint (0,0.1,0.1):
# Solving for bands 1 to 3...
#     iteration    7: trace = 0.5651397091670587 (0.19835% change)
#     iteration   15: trace = 0.5613238343068433 (0.0720586% change)
#     iteration   23: trace = 0.5603160085496904 (0.00201811% change)
#     iteration   30: trace = 0.5602929870304638 (0.000333897% change)
#     iteration   37: trace = 0.560284271572104 (7.85036e-05% change)
# Finished solving for bands 1 to 3 after 42 iterations.
# freqs:, 2, 0, 0.1, 0.1, 0.2, 0.127003, 0.127022, 0.726649
# elapsed time for k point: 23.0346288681
# solve_kpoint (0,0.2,0.2):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.6350401378690723 (0.0217197% change)
#     iteration   16: trace = 0.6348329835582938 (0.000170183% change)
# Finished solving for bands 1 to 3 after 23 iterations.
# freqs:, 3, 0, 0.2, 0.2, 0.4, 0.242729, 0.242775, 0.719009
# elapsed time for k point: 11.7539892197
# solve_kpoint (0,0.3,0.3):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.7457457916803314 (0.0142296% change)
#     iteration   16: trace = 0.7455920430533002 (0.000134348% change)
# Finished solving for bands 1 to 3 after 23 iterations.
# freqs:, 4, 0, 0.3, 0.3, 0.6, 0.33397, 0.334053, 0.722816
# elapsed time for k point: 11.7406060696
# solve_kpoint (0,0.4,0.4):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8508863430036495 (0.0137388% change)
#     iteration   16: trace = 0.8506770596130802 (0.000165421% change)
#     iteration   24: trace = 0.8506744315861368 (1.62126e-05% change)
# Finished solving for bands 1 to 3 after 26 iterations.
# freqs:, 5, 0, 0.4, 0.4, 0.8, 0.389322, 0.389439, 0.739891
# elapsed time for k point: 13.3056900501
# solve_kpoint (0,0.5,0.5):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.9065527073717479 (0.0226361% change)
#     iteration   16: trace = 0.904886975015192 (0.0434072% change)
#     iteration   24: trace = 0.9034292079637136 (0.00234674% change)
#     iteration   32: trace = 0.9034026285799073 (3.82449e-05% change)
#     iteration   40: trace = 0.9034000799684938 (5.48385e-05% change)
#     iteration   48: trace = 0.903396214067686 (5.0424e-05% change)
#     iteration   56: trace = 0.9033928469757608 (5.67447e-05% change)
#     iteration   64: trace = 0.9033660817765286 (0.000998015% change)
#     iteration   72: trace = 0.9032425423847528 (0.000941679% change)
#     iteration   80: trace = 0.9032225625183675 (9.25415e-05% change)
#     iteration   88: trace = 0.9032154966407073 (8.87155e-05% change)
#     iteration   96: trace = 0.9032123573848504 (1.803e-05% change)
# Finished solving for bands 1 to 3 after 99 iterations.
# freqs:, 6, 0, 0.5, 0.5, 1, 0.407002, 0.407132, 0.756178
# elapsed time for k point: 49.336220026
# solve_kpoint (0,0.525,0.475):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.9042294281453562 (0.00729051% change)
#     iteration   16: trace = 0.9040233021731677 (0.000250388% change)
#     iteration   24: trace = 0.9040173570519094 (9.14435e-05% change)
#     iteration   32: trace = 0.9037106311949188 (0.0131954% change)
#     iteration   40: trace = 0.9029824136620959 (0.00564027% change)
#     iteration   48: trace = 0.9027549758690286 (0.00178706% change)
#     iteration   56: trace = 0.9026600254183442 (0.00110635% change)
#     iteration   64: trace = 0.9025933635819342 (0.000743722% change)
#     iteration   72: trace = 0.9024544896047286 (0.00221625% change)
#     iteration   80: trace = 0.9024390357721865 (4.19993e-05% change)
#     iteration   88: trace = 0.9024358901149339 (8.32086e-05% change)
#     iteration   96: trace = 0.9024306080097557 (2.79224e-05% change)
#     iteration  104: trace = 0.9024283787206674 (3.49391e-05% change)
#     iteration  112: trace = 0.9024254275078685 (4.29675e-05% change)
# Finished solving for bands 1 to 3 after 117 iterations.
# freqs:, 7, 0, 0.525, 0.475, 1.0025, 0.407038, 0.407492, 0.755443
# elapsed time for k point: 58.3772130013
# solve_kpoint (0,0.55,0.45):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8997041112443174 (0.0083754% change)
#     iteration   16: trace = 0.8995947389360007 (5.07895e-05% change)
# Finished solving for bands 1 to 3 after 20 iterations.
# freqs:, 8, 0, 0.55, 0.45, 1.00995, 0.407084, 0.408472, 0.753012
# elapsed time for k point: 10.2556581497
# solve_kpoint (0,0.575,0.425):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8955896544193693 (0.00588289% change)
#     iteration   16: trace = 0.8955069457098246 (5.53187e-05% change)
#     iteration   24: trace = 0.8955043777084998 (4.35207e-05% change)
# Finished solving for bands 1 to 3 after 28 iterations.
# freqs:, 9, 0, 0.575, 0.425, 1.02225, 0.406949, 0.409771, 0.749656
# elapsed time for k point: 14.2353639603
# solve_kpoint (0,0.6,0.4):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8904921379273475 (0.00395973% change)
#     iteration   16: trace = 0.890432301633756 (4.0526e-05% change)
#     iteration   24: trace = 0.8904292029578124 (0.000185921% change)
#     iteration   32: trace = 0.8902476704884081 (0.00100717% change)
#     iteration   40: trace = 0.8901839384869077 (0.000847488% change)
#     iteration   48: trace = 0.8901244785488881 (0.000830033% change)
#     iteration   56: trace = 0.890066544887686 (0.000798082% change)
#     iteration   64: trace = 0.8900100985524872 (0.00079753% change)
#     iteration   72: trace = 0.884933513886612 (0.193094% change)
#     iteration   80: trace = 0.8832786623094679 (0.0157414% change)
#     iteration   88: trace = 0.8828589870030752 (0.00171427% change)
#     iteration   96: trace = 0.8828060466024494 (0.000571797% change)
#     iteration  104: trace = 0.8827676580107534 (0.000238998% change)
#     iteration  112: trace = 0.8827636660960428 (1.66002e-05% change)
# Finished solving for bands 1 to 3 after 116 iterations.
# freqs:, 10, 0, 0.6, 0.4, 1.03923, 0.406315, 0.410898, 0.740833
# elapsed time for k point: 57.7472321987
# solve_kpoint (0,0.625,0.375):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8686613242867547 (0.00253712% change)
#     iteration   16: trace = 0.8686262660953123 (1.2682e-05% change)
# Finished solving for bands 1 to 3 after 17 iterations.
# freqs:, 11, 0, 0.625, 0.375, 1.06066, 0.404743, 0.411177, 0.731944
# elapsed time for k point: 8.77080583572
# solve_kpoint (0,0.6,0.3):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8482835737400025 (0.0133625% change)
#     iteration   16: trace = 0.8476479807022881 (0.00415166% change)
#     iteration   24: trace = 0.8475955293702689 (5.62239e-05% change)
# Finished solving for bands 1 to 3 after 27 iterations.
# freqs:, 12, 0, 0.6, 0.3, 0.994987, 0.399983, 0.407361, 0.722264
# elapsed time for k point: 13.6988968849
# solve_kpoint (0,0.575,0.225):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8209130915440154 (0.00787016% change)
#     iteration   16: trace = 0.8207331435456904 (0.000826863% change)
#     iteration   24: trace = 0.8207192919873705 (1.87938e-05% change)
# Finished solving for bands 1 to 3 after 26 iterations.
# freqs:, 13, 0, 0.575, 0.225, 0.940744, 0.392301, 0.398609, 0.712692
# elapsed time for k point: 13.2039041519
# solve_kpoint (0,0.55,0.15):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.7953007728379309 (0.00605967% change)
#     iteration   16: trace = 0.7952184480815228 (0.000256762% change)
#     iteration   24: trace = 0.7952129786585285 (1.49915e-05% change)
#     iteration   32: trace = 0.7952119417005312 (1.65865e-05% change)
# Finished solving for bands 1 to 3 after 34 iterations.
# freqs:, 14, 0, 0.55, 0.15, 0.9, 0.384557, 0.388298, 0.704664
# elapsed time for k point: 17.2721500397
# solve_kpoint (0,0.525,0.075):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.7771645031373612 (0.00458469% change)
#     iteration   16: trace = 0.777121290827402 (8.77312e-05% change)
# Finished solving for bands 1 to 3 after 23 iterations.
# freqs:, 15, 0, 0.525, 0.075, 0.874643, 0.37896, 0.380115, 0.699301
# elapsed time for k point: 11.7206571102
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.7706228729542319 (0.00365019% change)
#     iteration   16: trace = 0.7705945679596398 (3.4246e-05% change)
#     iteration   24: trace = 0.7705933789097388 (3.55853e-05% change)
#     iteration   32: trace = 0.7705788562514774 (0.000813105% change)
#     iteration   40: trace = 0.7704218538444507 (0.000783153% change)
#     iteration   48: trace = 0.7704129592649214 (3.28083e-05% change)
# Finished solving for bands 1 to 3 after 51 iterations.
# freqs:, 16, 0, 0.5, 0, 0.866025, 0.376883, 0.377055, 0.697282
# elapsed time for k point: 25.5777699947
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.7454150537043575 (0.00999248% change)
#     iteration   16: trace = 0.7453420495315257 (8.48297e-05% change)
# Finished solving for bands 1 to 3 after 20 iterations.
# freqs:, 17, 0, 0.4, 0, 0.69282, 0.356121, 0.356274, 0.701134
# elapsed time for k point: 10.2289800644
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.6827414824018825 (0.0130217% change)
#     iteration   16: trace = 0.6826264879321808 (0.000184611% change)
# Finished solving for bands 1 to 3 after 21 iterations.
# freqs:, 18, 0, 0.3, 0, 0.519615, 0.298126, 0.298234, 0.710495
# elapsed time for k point: 10.735918045
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.6108170272688911 (0.0262921% change)
#     iteration   16: trace = 0.6106030523709733 (0.000427042% change)
# Finished solving for bands 1 to 3 after 23 iterations.
# freqs:, 19, 0, 0.2, 0, 0.34641, 0.212667, 0.212731, 0.721192
# elapsed time for k point: 11.7228131294
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.5568976795277858 (0.0649673% change)
#     iteration   16: trace = 0.5565494038346385 (0.000554672% change)
#     iteration   24: trace = 0.5565428539579641 (1.53369e-05% change)
# Finished solving for bands 1 to 3 after 25 iterations.
# freqs:, 20, 0, 0.1, 0, 0.173205, 0.11026, 0.110288, 0.729535
# elapsed time for k point: 12.7196989059
# solve_kpoint (0,0,0):
# Solving for bands 3 to 3...
#     iteration   23: trace = 0.5368485588091549 (2.16521e-05% change)
# Finished solving for bands 3 to 3 after 25 iterations.
# freqs:, 21, 0, 0, 0, 0, 0, 0, 0.732699
# elapsed time for k point: 4.31564188004
# solve_kpoint (0,0.1,0.1):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.562495684753187 (0.0895716% change)
#     iteration   16: trace = 0.5606571991569985 (0.0351867% change)
#     iteration   24: trace = 0.5602601631340285 (0.000577768% change)
#     iteration   32: trace = 0.560254666332058 (3.35058e-05% change)
# Finished solving for bands 1 to 3 after 39 iterations.
# freqs:, 22, 0, 0.1, 0.1, 0.2, 0.127003, 0.127022, 0.726629
# elapsed time for k point: 19.6687750816
# solve_kpoint (0,0.2,0.2):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.6350005800151396 (0.0209253% change)
#     iteration   16: trace = 0.6348013865831215 (0.000131925% change)
# Finished solving for bands 1 to 3 after 22 iterations.
# freqs:, 23, 0, 0.2, 0.2, 0.4, 0.242729, 0.242775, 0.718987
# elapsed time for k point: 11.2227668762
# solve_kpoint (0,0.3,0.3):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.7456854179350434 (0.013183% change)
#     iteration   16: trace = 0.7455456466755734 (9.67251e-05% change)
# Finished solving for bands 1 to 3 after 21 iterations.
# freqs:, 24, 0, 0.3, 0.3, 0.6, 0.33397, 0.334053, 0.722784
# elapsed time for k point: 10.7457039356
# solve_kpoint (0,0.4,0.4):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8507774260473137 (0.0127744% change)
#     iteration   16: trace = 0.850581605482263 (0.000162905% change)
#     iteration   24: trace = 0.8505793753488096 (1.09198e-05% change)
# Finished solving for bands 1 to 3 after 25 iterations.
# freqs:, 25, 0, 0.4, 0.4, 0.8, 0.389322, 0.389439, 0.739827
# elapsed time for k point: 12.8051009178
# solve_kpoint (0,0.5,0.5):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.9064010210698341 (0.0230685% change)
#     iteration   16: trace = 0.9047491951319204 (0.0427807% change)
#     iteration   24: trace = 0.9032485543602244 (0.00238771% change)
#     iteration   32: trace = 0.9032222300362596 (3.57731e-05% change)
#     iteration   40: trace = 0.9032210129007208 (2.07343e-05% change)
#     iteration   48: trace = 0.9032194929129309 (1.04893e-05% change)
# Finished solving for bands 1 to 3 after 49 iterations.
# freqs:, 26, 0, 0.5, 0.5, 1, 0.407002, 0.407132, 0.756183
# elapsed time for k point: 24.5862140656
# solve_kpoint (0.05,0.55,0.5):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.9032757531567053 (0.0219966% change)
#     iteration   16: trace = 0.9026523377931828 (0.00588483% change)
#     iteration   24: trace = 0.9022682178819219 (0.00283676% change)
#     iteration   32: trace = 0.9021637848049842 (0.000224017% change)
# Finished solving for bands 1 to 3 after 38 iterations.
# freqs:, 27, 0.05, 0.55, 0.5, 1.00499, 0.407401, 0.407531, 0.755053
# elapsed time for k point: 19.2557079792
# solve_kpoint (0.1,0.6,0.5):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8976167176713192 (0.0342569% change)
#     iteration   16: trace = 0.8958753407981423 (0.0146057% change)
#     iteration   24: trace = 0.895546622664359 (0.00064582% change)
#     iteration   32: trace = 0.8955293522021059 (4.04775e-05% change)
#     iteration   40: trace = 0.8955278705457338 (3.79774e-05% change)
#     iteration   48: trace = 0.8954877296259872 (0.00107744% change)
#     iteration   56: trace = 0.8954588814604932 (6.78495e-05% change)
#     iteration   64: trace = 0.8954559339669268 (3.26559e-05% change)
# Finished solving for bands 1 to 3 after 68 iterations.
# freqs:, 28, 0.1, 0.6, 0.5, 1.0198, 0.40845, 0.408581, 0.749457
# elapsed time for k point: 34.0733730793
# solve_kpoint (0.15,0.65,0.5):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8876139118758508 (0.00994408% change)
#     iteration   16: trace = 0.8872776894579614 (0.00186847% change)
#     iteration   24: trace = 0.887245013408243 (3.81555e-05% change)
# Finished solving for bands 1 to 3 after 28 iterations.
# freqs:, 29, 0.15, 0.65, 0.5, 1.04403, 0.409759, 0.409893, 0.742516
# elapsed time for k point: 14.3099370003
# solve_kpoint (0.2,0.7,0.5):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8816193371581835 (0.00410695% change)
#     iteration   16: trace = 0.8815131609916641 (0.000426358% change)
#     iteration   24: trace = 0.8815061919744243 (7.81475e-06% change)
# Finished solving for bands 1 to 3 after 24 iterations.
# freqs:, 30, 0.2, 0.7, 0.5, 1.07703, 0.410828, 0.410965, 0.737451
# elapsed time for k point: 12.2648470402
# solve_kpoint (0.25,0.75,0.5):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8795738661426553 (0.0028085% change)
#     iteration   16: trace = 0.8795115783068775 (0.00021141% change)
#     iteration   23: trace = 0.8795079170333031 (8.7316e-06% change)
# Finished solving for bands 1 to 3 after 23 iterations.
# freqs:, 31, 0.25, 0.75, 0.5, 1.11803, 0.411238, 0.411379, 0.735635
# elapsed time for k point: 12.8301508427
# solve_kpoint (0.275,0.75,0.475):
# Solving for bands 1 to 3...
#     iteration    7: trace = 0.8764008304319971 (0.00703786% change)
#     iteration   15: trace = 0.8762795645076678 (0.000362914% change)
# Finished solving for bands 1 to 3 after 21 iterations.
# freqs:, 32, 0.275, 0.75, 0.475, 1.09772, 0.410041, 0.411742, 0.733902
# elapsed time for k point: 11.5970640182
# solve_kpoint (0.3,0.75,0.45):
# Solving for bands 1 to 3...
#     iteration    7: trace = 0.8732130319481657 (0.0097595% change)
#     iteration   14: trace = 0.873055448980391 (0.000586209% change)
# Finished solving for bands 1 to 3 after 21 iterations.
# freqs:, 33, 0.3, 0.75, 0.45, 1.08167, 0.408245, 0.411694, 0.73273
# elapsed time for k point: 11.7999510765
# solve_kpoint (0.325,0.75,0.425):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8705848827235702 (0.00570163% change)
#     iteration   16: trace = 0.8704249266040568 (0.000166422% change)
# Finished solving for bands 1 to 3 after 21 iterations.
# freqs:, 34, 0.325, 0.75, 0.425, 1.07005, 0.40653, 0.41143, 0.73204
# elapsed time for k point: 10.7432079315
# solve_kpoint (0.35,0.75,0.4):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8689469185686326 (0.00715475% change)
#     iteration   16: trace = 0.8687535277491435 (0.000181663% change)
# Finished solving for bands 1 to 3 after 22 iterations.
# freqs:, 35, 0.35, 0.75, 0.4, 1.06301, 0.405322, 0.411179, 0.731708
# elapsed time for k point: 11.3260669708
# solve_kpoint (0.375,0.75,0.375):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.868401334841278 (0.00806188% change)
#     iteration   16: trace = 0.8681857580314121 (0.000189726% change)
# Finished solving for bands 1 to 3 after 22 iterations.
# freqs:, 36, 0.375, 0.75, 0.375, 1.06066, 0.404889, 0.411079, 0.731616
# elapsed time for k point: 11.2549459934
# solve_kpoint (0.3,0.6,0.3):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.8116964568862204 (0.0191826% change)
#     iteration   16: trace = 0.8115264899090415 (6.5647e-05% change)
# Finished solving for bands 1 to 3 after 20 iterations.
# freqs:, 37, 0.3, 0.6, 0.3, 0.848528, 0.38855, 0.398182, 0.708524
# elapsed time for k point: 10.2481749058
# solve_kpoint (0.225,0.45,0.225):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.7292238450483408 (0.0144705% change)
#     iteration   16: trace = 0.7291128500056566 (5.47461e-05% change)
# Finished solving for bands 1 to 3 after 20 iterations.
# freqs:, 38, 0.225, 0.45, 0.225, 0.636396, 0.340948, 0.347899, 0.701308
# elapsed time for k point: 10.2509701252
# solve_kpoint (0.15,0.3,0.15):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.6344062548617104 (0.0177703% change)
#     iteration   16: trace = 0.6342686026339829 (8.95118e-05% change)
# Finished solving for bands 1 to 3 after 21 iterations.
# freqs:, 39, 0.15, 0.3, 0.15, 0.424264, 0.253223, 0.255623, 0.710495
# elapsed time for k point: 10.8214480877
# solve_kpoint (0.075,0.15,0.075):
# Solving for bands 1 to 3...
#     iteration    8: trace = 0.5623253104885479 (0.0590112% change)
#     iteration   16: trace = 0.5620047482347167 (0.000299671% change)
# Finished solving for bands 1 to 3 after 22 iterations.
# freqs:, 40, 0.075, 0.15, 0.075, 0.212132, 0.134194, 0.134485, 0.725196
# elapsed time for k point: 11.229049921
# solve_kpoint (0,0,0):
# Solving for bands 3 to 3...
#     iteration   23: trace = 0.5369011301286969 (1.04854e-05% change)
# Finished solving for bands 3 to 3 after 24 iterations.
# freqs:, 41, 0, 0, 0, 0, 0, 0, 0.732735
# elapsed time for k point: 4.16068387032
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.411238272564 at Vector3<0.25, 0.75, 0.5>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.41174160686 at Vector3<0.275, 0.75, 0.475>
# Band 3 range: 0.697281679219 at Vector3<0.0, 0.5, 0.0> to 0.756182888786 at Vector3<0.0, 0.5, 0.5>
# Gap from band 2 (0.41174160686) to band 3 (0.697281679219), 51.4939723886%
# total elapsed time for run: 670.760221004
# done
# epsilon: 1-32, mean 4.0836, harm. mean 1.12255, 12.0377% > 1, 9.9471% "fill"
# Outputting PIT-epsilon.h5...
#
# Elapsed run time = 670.9582 s

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
num_bands=3
nip_raw = []
k_raw = []
omega_raw = []

with open('PI.dat') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    next(csv_file)
    for row in csv_reader:
        nip_raw.append(row[1])
        k_raw.append(row[2:5])
        omega_raw.append(row[6:num_bands+6])

# %%
N=np.size(nip_raw)
nip=np.zeros((N))
k=np.zeros((N,3))
omega=np.zeros((N,num_bands))
for i in range(0,N):
    nip[i] = float(nip_raw[i])
    for j in range(0,3):
        k[i][j] = float(k_raw[i][j])
        
    for j in range(0,num_bands):
        omega[i][j] = float(omega_raw[i][j])

plt.plot(nip,omega[:,:])
# Out:
# [<matplotlib.lines.Line2D at 0x1197da350>,
#  <matplotlib.lines.Line2D at 0x1197da410>,
#  <matplotlib.lines.Line2D at 0x1197da4d0>]

# %%
import math
import meep as mp
from meep import mpb
num_bands = 8
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(0.5),       # X
            mp.Vector3(0.5, 0.5),  # M
            mp.Vector3()]          # Gamma
k_points = mp.interpolate(4, k_points)
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1))
resolution = 32
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)
print("Square lattice of rods: TE bands")
ms.run_tm()
ms.output_epsilon()
# Out:
# Square lattice of rods: TE bands
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.3, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.3, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.2, 0.2, 0.0>
#   Vector3<0.1, 0.1, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.00442099571228
# elapsed time for k point: 0.0479300022125
# elapsed time for k point: 0.061646938324
# elapsed time for k point: 0.0220170021057
# elapsed time for k point: 0.0182199478149
# elapsed time for k point: 0.0210120677948
# elapsed time for k point: 0.0230560302734
# elapsed time for k point: 0.0188121795654
# elapsed time for k point: 0.0219480991364
# elapsed time for k point: 0.0232241153717
# elapsed time for k point: 0.0215079784393
# elapsed time for k point: 0.0223231315613
# elapsed time for k point: 0.0246047973633
# elapsed time for k point: 0.0184109210968
# elapsed time for k point: 0.0176680088043
# elapsed time for k point: 0.0210919380188
# elapsed time for k point: 0.0264959335327
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28094795584 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.417114249412 at Vector3<0.5, 0.0, 0.0> to 0.546026798503 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.49619745357 at Vector3<0.5, 0.5, 0.0> to 0.557657636378 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.552095588382 at Vector3<0.0, 0.0, 0.0> to 0.713395151752 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.741310965861 at Vector3<0.5, 0.0, 0.0> to 0.85947410811 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.829517617504 at Vector3<0.3, 0.3, 0.0> to 0.878315571849 at Vector3<0.5, 0.5, 0.0>
# Band 7 range: 0.862515905877 at Vector3<0.5, 0.0, 0.0> to 0.951107462574 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.879351095841 at Vector3<0.5, 0.5, 0.0> to 1.08259340136 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.28094795584) to band 2 (0.417114249412), 39.0126531838%
# Gap from band 4 (0.713395151752) to band 5 (0.741310965861), 3.83800051031%
# total elapsed time for run: 0.421555042267
# done
# Outputting epsilon.h5...

# %%
#!python PIT.py >& PI.out
#!rm PI.dat
#!rm *.h5
#!grep tmfreqs PI.out >> PI.dat

import csv
import numpy as np
import matplotlib.pyplot as plt
num_bands=8
nip_raw = []
k_raw = []
omega_raw = []

with open('PI.dat') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    next(csv_file)
    for row in csv_reader:
        nip_raw.append(row[1])
        k_raw.append(row[2:5])
        omega_raw.append(row[6:num_bands+6])
        
N=np.size(nip_raw)
nip=np.zeros((N))
k=np.zeros((N,3))
omega=np.zeros((N,num_bands))
for i in range(0,N):
    nip[i] = float(nip_raw[i])
    for j in range(0,3):
        k[i][j] = float(k_raw[i][j])
        
    for j in range(0,num_bands):
        omega[i][j] = float(omega_raw[i][j])

plt.plot(nip,omega[:,:])
# Out:
# rm: PI.dat: No such file or directory
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-68-87bf110a152e> in <module>()
#      15     csv_reader = csv.reader(csv_file, delimiter=',')
#      16     line_count = 0
# ---> 17     next(csv_file)
#      18     for row in csv_reader:
#      19         nip_raw.append(row[1])
#
# StopIteration:

# %%
import math
(0.57735/0.408)*math.sqrt(2)
# Out:
# 2.001216177049281

# %%
# !python PIT.py 
# !h5tovtk PIT-epsilon.h5
# Out:
# Square lattice of rods: TE bands
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.3, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.3, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.2, 0.2, 0.0>
#   Vector3<0.1, 0.1, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.00147700309753
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 19 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.0338928699493
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 19 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.1, 0.0643671, 0.518896, 0.552617, 0.579095, 0.812721, 0.852958, 0.941428, 1.04995
# elapsed time for k point: 0.0524060726166
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.2, 0.126061, 0.48795, 0.553991, 0.610359, 0.812384, 0.849484, 0.912816, 1.02959
# elapsed time for k point: 0.0234520435333
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.3, 0.181523, 0.45665, 0.555709, 0.644685, 0.802314, 0.845326, 0.880698, 1.025
# elapsed time for k point: 0.0227599143982
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.4, 0.224302, 0.429317, 0.557116, 0.682524, 0.772176, 0.842059, 0.865404, 1.0269
# elapsed time for k point: 0.0216519832611
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.5, 0.241821, 0.417114, 0.557658, 0.713395, 0.741311, 0.84083, 0.862516, 1.02856
# elapsed time for k point: 0.0249361991882
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, 0.5, 0.1, 0, 0.509902, 0.245235, 0.4236, 0.551085, 0.711571, 0.749855, 0.841982, 0.862609, 1.01714
# elapsed time for k point: 0.0193030834198
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 8, 0.5, 0.2, 0, 0.538516, 0.25442, 0.441321, 0.535034, 0.706018, 0.772267, 0.845818, 0.862861, 0.989395
# elapsed time for k point: 0.0156841278076
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 9, 0.5, 0.3, 0, 0.583095, 0.266397, 0.465222, 0.516482, 0.697068, 0.802974, 0.853388, 0.863228, 0.954203
# elapsed time for k point: 0.0203759670258
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 10, 0.5, 0.4, 0, 0.640312, 0.276774, 0.48701, 0.501823, 0.687264, 0.837704, 0.86397, 0.865932, 0.916273
# elapsed time for k point: 0.0211539268494
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 11, 0.5, 0.5, 0, 0.707107, 0.280948, 0.496196, 0.496197, 0.682617, 0.859474, 0.878316, 0.878316, 0.879351
# elapsed time for k point: 0.025269985199
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 12, 0.4, 0.4, 0, 0.565685, 0.27141, 0.485365, 0.501693, 0.689111, 0.830636, 0.844978, 0.893706, 0.898991
# elapsed time for k point: 0.0261859893799
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.236529, 0.473888, 0.515941, 0.679199, 0.819377, 0.829518, 0.897603, 0.933446
# elapsed time for k point: 0.0193841457367
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 14, 0.2, 0.2, 0, 0.282843, 0.172884, 0.482973, 0.533242, 0.640233, 0.819202, 0.838111, 0.910409, 0.976551
# elapsed time for k point: 0.0227961540222
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 15, 0.1, 0.1, 0, 0.141421, 0.0904174, 0.510404, 0.546943, 0.593803, 0.81373, 0.851132, 0.935551, 1.02882
# elapsed time for k point: 0.0248019695282
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 15 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.0306420326233
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28094795584 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.417114249412 at Vector3<0.5, 0.0, 0.0> to 0.546026798503 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.49619745357 at Vector3<0.5, 0.5, 0.0> to 0.557657636378 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.552095589116 at Vector3<0.0, 0.0, 0.0> to 0.713395151752 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.741310965861 at Vector3<0.5, 0.0, 0.0> to 0.85947410811 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.829517617504 at Vector3<0.3, 0.3, 0.0> to 0.878315571849 at Vector3<0.5, 0.5, 0.0>
# Band 7 range: 0.862515905877 at Vector3<0.5, 0.0, 0.0> to 0.951107462574 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.879351095841 at Vector3<0.5, 0.5, 0.0> to 1.08259315863 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.28094795584) to band 2 (0.417114249412), 39.0126531838%
# Gap from band 4 (0.713395151752) to band 5 (0.741310965861), 3.83800051031%
# total elapsed time for run: 0.407442808151
# done
# epsilon: 1-12, mean 2.38229, harm. mean 1.1448, 14.5508% > 1, 12.5663% "fill"
# Outputting PIT-epsilon.h5...
#
# Elapsed run time = 0.4499 s
